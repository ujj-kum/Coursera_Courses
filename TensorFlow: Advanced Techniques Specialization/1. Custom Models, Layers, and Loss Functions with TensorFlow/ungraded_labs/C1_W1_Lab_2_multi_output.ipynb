# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %%
## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train.columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
# optimizer = tf.keras.optimizers.SGD(lr=0.001)
# model.compile(optimizer=optimizer,
#               loss={'y1_output': 'mse', 'y2_output': 'mse'},
#               metrics={'y1_output': 'accuracy',
#                        'y2_output': 'accuracy'})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=100, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/100
# 614/614 [==============================] - 1s 1ms/sample - loss: 234.2044 - y1_output_loss: 110.5109 - y2_output_loss: 121.8340 - y1_output_root_mean_squared_error: 10.5579 - y2_output_root_mean_squared_error: 11.0786 - val_loss: 49.4759 - val_y1_output_loss: 18.1531 - val_y2_output_loss: 30.8447 - val_y1_output_root_mean_squared_error: 4.3032 - val_y2_output_root_mean_squared_error: 5.5640
# Epoch 2/100
# 614/614 [==============================] - 0s 213us/sample - loss: 31.7394 - y1_output_loss: 12.0662 - y2_output_loss: 20.1270 - y1_output_root_mean_squared_error: 3.4620 - y2_output_root_mean_squared_error: 4.4446 - val_loss: 62.5105 - val_y1_output_loss: 15.4572 - val_y2_output_loss: 44.9849 - val_y1_output_root_mean_squared_error: 3.9980 - val_y2_output_root_mean_squared_error: 6.8210
# Epoch 3/100
# 614/614 [==============================] - 0s 191us/sample - loss: 23.6250 - y1_output_loss: 9.5388 - y2_output_loss: 14.1870 - y1_output_root_mean_squared_error: 3.0693 - y2_output_root_mean_squared_error: 3.7688 - val_loss: 25.7438 - val_y1_output_loss: 11.3951 - val_y2_output_loss: 13.9738 - val_y1_output_root_mean_squared_error: 3.4192 - val_y2_output_root_mean_squared_error: 3.7487
# Epoch 4/100
# 614/614 [==============================] - 0s 190us/sample - loss: 27.8977 - y1_output_loss: 10.4940 - y2_output_loss: 17.8409 - y1_output_root_mean_squared_error: 3.2159 - y2_output_root_mean_squared_error: 4.1899 - val_loss: 44.3331 - val_y1_output_loss: 14.1018 - val_y2_output_loss: 29.8285 - val_y1_output_root_mean_squared_error: 3.7914 - val_y2_output_root_mean_squared_error: 5.4734
# Epoch 5/100
# 614/614 [==============================] - 0s 178us/sample - loss: 29.4719 - y1_output_loss: 10.3337 - y2_output_loss: 19.0667 - y1_output_root_mean_squared_error: 3.2211 - y2_output_root_mean_squared_error: 4.3700 - val_loss: 21.8178 - val_y1_output_loss: 9.8569 - val_y2_output_loss: 11.4330 - val_y1_output_root_mean_squared_error: 3.1815 - val_y2_output_root_mean_squared_error: 3.4199
# Epoch 6/100
# 614/614 [==============================] - 0s 203us/sample - loss: 22.4823 - y1_output_loss: 8.9657 - y2_output_loss: 13.6721 - y1_output_root_mean_squared_error: 2.9829 - y2_output_root_mean_squared_error: 3.6857 - val_loss: 34.2348 - val_y1_output_loss: 11.6663 - val_y2_output_loss: 22.4312 - val_y1_output_root_mean_squared_error: 3.4511 - val_y2_output_root_mean_squared_error: 4.7249
# Epoch 7/100
# 614/614 [==============================] - 0s 186us/sample - loss: 25.2059 - y1_output_loss: 9.0770 - y2_output_loss: 16.2786 - y1_output_root_mean_squared_error: 2.9855 - y2_output_root_mean_squared_error: 4.0364 - val_loss: 25.9845 - val_y1_output_loss: 9.8411 - val_y2_output_loss: 15.9823 - val_y1_output_root_mean_squared_error: 3.1734 - val_y2_output_root_mean_squared_error: 3.9892
# Epoch 8/100
# 614/614 [==============================] - 0s 180us/sample - loss: 28.1244 - y1_output_loss: 9.5620 - y2_output_loss: 19.0558 - y1_output_root_mean_squared_error: 3.0865 - y2_output_root_mean_squared_error: 4.3125 - val_loss: 26.9514 - val_y1_output_loss: 10.1914 - val_y2_output_loss: 16.5281 - val_y1_output_root_mean_squared_error: 3.2315 - val_y2_output_root_mean_squared_error: 4.0631
# Epoch 9/100
# 614/614 [==============================] - 0s 171us/sample - loss: 31.3592 - y1_output_loss: 9.9005 - y2_output_loss: 21.4107 - y1_output_root_mean_squared_error: 3.1424 - y2_output_root_mean_squared_error: 4.6352 - val_loss: 37.9400 - val_y1_output_loss: 10.9234 - val_y2_output_loss: 26.9832 - val_y1_output_root_mean_squared_error: 3.3334 - val_y2_output_root_mean_squared_error: 5.1796
# Epoch 10/100
# 614/614 [==============================] - 0s 163us/sample - loss: 21.3118 - y1_output_loss: 8.3838 - y2_output_loss: 13.2152 - y1_output_root_mean_squared_error: 2.8805 - y2_output_root_mean_squared_error: 3.6076 - val_loss: 36.4617 - val_y1_output_loss: 11.0672 - val_y2_output_loss: 25.1868 - val_y1_output_root_mean_squared_error: 3.3696 - val_y2_output_root_mean_squared_error: 5.0108
# Epoch 11/100
# 614/614 [==============================] - 0s 171us/sample - loss: 22.5024 - y1_output_loss: 8.3693 - y2_output_loss: 14.2413 - y1_output_root_mean_squared_error: 2.8945 - y2_output_root_mean_squared_error: 3.7582 - val_loss: 23.6527 - val_y1_output_loss: 10.7477 - val_y2_output_loss: 12.4109 - val_y1_output_root_mean_squared_error: 3.3221 - val_y2_output_root_mean_squared_error: 3.5519
# Epoch 12/100
# 614/614 [==============================] - 0s 162us/sample - loss: 19.1391 - y1_output_loss: 7.7807 - y2_output_loss: 11.3999 - y1_output_root_mean_squared_error: 2.7735 - y2_output_root_mean_squared_error: 3.3833 - val_loss: 19.1996 - val_y1_output_loss: 8.7337 - val_y2_output_loss: 10.0321 - val_y1_output_root_mean_squared_error: 2.9992 - val_y2_output_root_mean_squared_error: 3.1945
# Epoch 13/100
# 614/614 [==============================] - 0s 179us/sample - loss: 21.8424 - y1_output_loss: 8.2653 - y2_output_loss: 13.5773 - y1_output_root_mean_squared_error: 2.8556 - y2_output_root_mean_squared_error: 3.6997 - val_loss: 19.3403 - val_y1_output_loss: 9.4746 - val_y2_output_loss: 9.4360 - val_y1_output_root_mean_squared_error: 3.1241 - val_y2_output_root_mean_squared_error: 3.0952
# Epoch 14/100
# 614/614 [==============================] - 0s 177us/sample - loss: 19.0066 - y1_output_loss: 7.3971 - y2_output_loss: 11.7680 - y1_output_root_mean_squared_error: 2.7025 - y2_output_root_mean_squared_error: 3.4210 - val_loss: 31.5895 - val_y1_output_loss: 11.0986 - val_y2_output_loss: 19.5729 - val_y1_output_root_mean_squared_error: 3.3796 - val_y2_output_root_mean_squared_error: 4.4908
# Epoch 15/100
# 614/614 [==============================] - 0s 168us/sample - loss: 20.7896 - y1_output_loss: 7.7057 - y2_output_loss: 12.9658 - y1_output_root_mean_squared_error: 2.7864 - y2_output_root_mean_squared_error: 3.6091 - val_loss: 19.9499 - val_y1_output_loss: 8.2556 - val_y2_output_loss: 11.5027 - val_y1_output_root_mean_squared_error: 2.9132 - val_y2_output_root_mean_squared_error: 3.3858
# Epoch 16/100
# 614/614 [==============================] - 0s 163us/sample - loss: 17.6754 - y1_output_loss: 6.9873 - y2_output_loss: 10.7541 - y1_output_root_mean_squared_error: 2.6465 - y2_output_root_mean_squared_error: 3.2667 - val_loss: 48.4010 - val_y1_output_loss: 11.7383 - val_y2_output_loss: 35.4475 - val_y1_output_root_mean_squared_error: 3.4658 - val_y2_output_root_mean_squared_error: 6.0323
# Epoch 17/100
# 614/614 [==============================] - 0s 170us/sample - loss: 20.1400 - y1_output_loss: 7.4780 - y2_output_loss: 12.8113 - y1_output_root_mean_squared_error: 2.7189 - y2_output_root_mean_squared_error: 3.5704 - val_loss: 45.8176 - val_y1_output_loss: 14.7475 - val_y2_output_loss: 30.8573 - val_y1_output_root_mean_squared_error: 3.8785 - val_y2_output_root_mean_squared_error: 5.5475
# Epoch 18/100
# 614/614 [==============================] - 0s 168us/sample - loss: 18.1985 - y1_output_loss: 7.2642 - y2_output_loss: 10.8280 - y1_output_root_mean_squared_error: 2.7040 - y2_output_root_mean_squared_error: 3.2996 - val_loss: 19.6008 - val_y1_output_loss: 8.3222 - val_y2_output_loss: 10.8346 - val_y1_output_root_mean_squared_error: 2.9219 - val_y2_output_root_mean_squared_error: 3.3262
# Epoch 19/100
# 614/614 [==============================] - 0s 170us/sample - loss: 17.7098 - y1_output_loss: 6.9349 - y2_output_loss: 10.7641 - y1_output_root_mean_squared_error: 2.6180 - y2_output_root_mean_squared_error: 3.2948 - val_loss: 21.8861 - val_y1_output_loss: 10.7432 - val_y2_output_loss: 10.6022 - val_y1_output_root_mean_squared_error: 3.3188 - val_y2_output_root_mean_squared_error: 3.2972
# Epoch 20/100
# 614/614 [==============================] - 0s 173us/sample - loss: 18.5236 - y1_output_loss: 7.1375 - y2_output_loss: 11.2873 - y1_output_root_mean_squared_error: 2.6705 - y2_output_root_mean_squared_error: 3.3752 - val_loss: 16.1980 - val_y1_output_loss: 7.3075 - val_y2_output_loss: 8.6332 - val_y1_output_root_mean_squared_error: 2.7431 - val_y2_output_root_mean_squared_error: 2.9451
# Epoch 21/100
# 614/614 [==============================] - 0s 165us/sample - loss: 16.4271 - y1_output_loss: 6.5370 - y2_output_loss: 9.8387 - y1_output_root_mean_squared_error: 2.5587 - y2_output_root_mean_squared_error: 3.1433 - val_loss: 17.7969 - val_y1_output_loss: 7.7436 - val_y2_output_loss: 9.8444 - val_y1_output_root_mean_squared_error: 2.8221 - val_y2_output_root_mean_squared_error: 3.1357
# Epoch 22/100
# 614/614 [==============================] - 0s 162us/sample - loss: 16.4688 - y1_output_loss: 6.6016 - y2_output_loss: 9.9355 - y1_output_root_mean_squared_error: 2.5678 - y2_output_root_mean_squared_error: 3.1425 - val_loss: 21.8164 - val_y1_output_loss: 9.3373 - val_y2_output_loss: 12.1302 - val_y1_output_root_mean_squared_error: 3.1002 - val_y2_output_root_mean_squared_error: 3.4936
# Epoch 23/100
# 614/614 [==============================] - 0s 174us/sample - loss: 20.0431 - y1_output_loss: 7.2086 - y2_output_loss: 12.7892 - y1_output_root_mean_squared_error: 2.6800 - y2_output_root_mean_squared_error: 3.5862 - val_loss: 23.9145 - val_y1_output_loss: 10.3969 - val_y2_output_loss: 12.8135 - val_y1_output_root_mean_squared_error: 3.2727 - val_y2_output_root_mean_squared_error: 3.6338
# Epoch 24/100
# 614/614 [==============================] - 0s 187us/sample - loss: 17.0951 - y1_output_loss: 6.4179 - y2_output_loss: 10.5916 - y1_output_root_mean_squared_error: 2.5386 - y2_output_root_mean_squared_error: 3.2635 - val_loss: 17.3616 - val_y1_output_loss: 7.2723 - val_y2_output_loss: 9.9919 - val_y1_output_root_mean_squared_error: 2.7317 - val_y2_output_root_mean_squared_error: 3.1464
# Epoch 25/100
# 614/614 [==============================] - 0s 186us/sample - loss: 13.7982 - y1_output_loss: 5.4237 - y2_output_loss: 8.4221 - y1_output_root_mean_squared_error: 2.3344 - y2_output_root_mean_squared_error: 2.8894 - val_loss: 46.3447 - val_y1_output_loss: 11.1124 - val_y2_output_loss: 33.8400 - val_y1_output_root_mean_squared_error: 3.3822 - val_y2_output_root_mean_squared_error: 5.9081
# Epoch 26/100
# 614/614 [==============================] - 0s 185us/sample - loss: 17.2206 - y1_output_loss: 6.0169 - y2_output_loss: 11.0816 - y1_output_root_mean_squared_error: 2.4606 - y2_output_root_mean_squared_error: 3.3416 - val_loss: 13.8810 - val_y1_output_loss: 6.2785 - val_y2_output_loss: 7.2209 - val_y1_output_root_mean_squared_error: 2.5439 - val_y2_output_root_mean_squared_error: 2.7221
# Epoch 27/100
# 614/614 [==============================] - 0s 172us/sample - loss: 13.6583 - y1_output_loss: 5.4016 - y2_output_loss: 8.3275 - y1_output_root_mean_squared_error: 2.3240 - y2_output_root_mean_squared_error: 2.8735 - val_loss: 12.6251 - val_y1_output_loss: 5.8306 - val_y2_output_loss: 6.4732 - val_y1_output_root_mean_squared_error: 2.4494 - val_y2_output_root_mean_squared_error: 2.5740
# Epoch 28/100
# 614/614 [==============================] - 0s 166us/sample - loss: 14.1289 - y1_output_loss: 5.1123 - y2_output_loss: 8.9154 - y1_output_root_mean_squared_error: 2.2664 - y2_output_root_mean_squared_error: 2.9987 - val_loss: 13.3155 - val_y1_output_loss: 6.0587 - val_y2_output_loss: 6.9974 - val_y1_output_root_mean_squared_error: 2.5001 - val_y2_output_root_mean_squared_error: 2.6580
# Epoch 29/100
# 614/614 [==============================] - 0s 166us/sample - loss: 13.3667 - y1_output_loss: 5.0448 - y2_output_loss: 8.2140 - y1_output_root_mean_squared_error: 2.2540 - y2_output_root_mean_squared_error: 2.8786 - val_loss: 13.3353 - val_y1_output_loss: 6.0602 - val_y2_output_loss: 7.0834 - val_y1_output_root_mean_squared_error: 2.4929 - val_y2_output_root_mean_squared_error: 2.6685
# Epoch 30/100
# 614/614 [==============================] - 0s 174us/sample - loss: 14.2173 - y1_output_loss: 5.2385 - y2_output_loss: 8.9821 - y1_output_root_mean_squared_error: 2.2832 - y2_output_root_mean_squared_error: 3.0007 - val_loss: 17.0862 - val_y1_output_loss: 6.1087 - val_y2_output_loss: 10.9271 - val_y1_output_root_mean_squared_error: 2.5059 - val_y2_output_root_mean_squared_error: 3.2873
# Epoch 31/100
# 614/614 [==============================] - 0s 174us/sample - loss: 12.6789 - y1_output_loss: 4.7945 - y2_output_loss: 7.8098 - y1_output_root_mean_squared_error: 2.1972 - y2_output_root_mean_squared_error: 2.8020 - val_loss: 12.3049 - val_y1_output_loss: 5.2610 - val_y2_output_loss: 6.8432 - val_y1_output_root_mean_squared_error: 2.3295 - val_y2_output_root_mean_squared_error: 2.6227
# Epoch 32/100
# 614/614 [==============================] - 0s 201us/sample - loss: 13.9499 - y1_output_loss: 4.9085 - y2_output_loss: 9.0283 - y1_output_root_mean_squared_error: 2.2071 - y2_output_root_mean_squared_error: 3.0131 - val_loss: 11.4872 - val_y1_output_loss: 5.2675 - val_y2_output_loss: 6.0183 - val_y1_output_root_mean_squared_error: 2.3305 - val_y2_output_root_mean_squared_error: 2.4609
# Epoch 33/100
# 614/614 [==============================] - 0s 188us/sample - loss: 11.7351 - y1_output_loss: 4.3359 - y2_output_loss: 7.5256 - y1_output_root_mean_squared_error: 2.0864 - y2_output_root_mean_squared_error: 2.7170 - val_loss: 36.6480 - val_y1_output_loss: 8.1678 - val_y2_output_loss: 27.6218 - val_y1_output_root_mean_squared_error: 2.8858 - val_y2_output_root_mean_squared_error: 5.3217
# Epoch 34/100
# 614/614 [==============================] - 0s 187us/sample - loss: 11.6526 - y1_output_loss: 4.4710 - y2_output_loss: 7.7161 - y1_output_root_mean_squared_error: 2.0798 - y2_output_root_mean_squared_error: 2.7068 - val_loss: 53.4939 - val_y1_output_loss: 12.7372 - val_y2_output_loss: 40.7142 - val_y1_output_root_mean_squared_error: 3.5993 - val_y2_output_root_mean_squared_error: 6.3670
# Epoch 35/100
# 614/614 [==============================] - 0s 171us/sample - loss: 13.2167 - y1_output_loss: 4.5457 - y2_output_loss: 8.5812 - y1_output_root_mean_squared_error: 2.1391 - y2_output_root_mean_squared_error: 2.9396 - val_loss: 11.7716 - val_y1_output_loss: 5.0057 - val_y2_output_loss: 6.5255 - val_y1_output_root_mean_squared_error: 2.2627 - val_y2_output_root_mean_squared_error: 2.5791
# Epoch 36/100
# 614/614 [==============================] - 0s 173us/sample - loss: 10.8420 - y1_output_loss: 3.9649 - y2_output_loss: 6.8754 - y1_output_root_mean_squared_error: 1.9878 - y2_output_root_mean_squared_error: 2.6250 - val_loss: 16.6441 - val_y1_output_loss: 6.3189 - val_y2_output_loss: 10.2784 - val_y1_output_root_mean_squared_error: 2.5422 - val_y2_output_root_mean_squared_error: 3.1909
# Epoch 37/100
# 614/614 [==============================] - 0s 173us/sample - loss: 10.7587 - y1_output_loss: 4.0097 - y2_output_loss: 6.6591 - y1_output_root_mean_squared_error: 2.0099 - y2_output_root_mean_squared_error: 2.5921 - val_loss: 11.9853 - val_y1_output_loss: 5.0125 - val_y2_output_loss: 6.6949 - val_y1_output_root_mean_squared_error: 2.2681 - val_y2_output_root_mean_squared_error: 2.6155
# Epoch 38/100
# 614/614 [==============================] - 0s 164us/sample - loss: 10.4216 - y1_output_loss: 3.9504 - y2_output_loss: 6.3976 - y1_output_root_mean_squared_error: 1.9958 - y2_output_root_mean_squared_error: 2.5374 - val_loss: 23.8523 - val_y1_output_loss: 8.3032 - val_y2_output_loss: 15.4241 - val_y1_output_root_mean_squared_error: 2.9114 - val_y2_output_root_mean_squared_error: 3.9212
# Epoch 39/100
# 614/614 [==============================] - 0s 163us/sample - loss: 12.6411 - y1_output_loss: 4.2148 - y2_output_loss: 8.3901 - y1_output_root_mean_squared_error: 2.0558 - y2_output_root_mean_squared_error: 2.9008 - val_loss: 15.0749 - val_y1_output_loss: 5.7899 - val_y2_output_loss: 9.2309 - val_y1_output_root_mean_squared_error: 2.4357 - val_y2_output_root_mean_squared_error: 3.0236
# Epoch 40/100
# 614/614 [==============================] - 0s 176us/sample - loss: 9.0101 - y1_output_loss: 3.6235 - y2_output_loss: 5.4631 - y1_output_root_mean_squared_error: 1.8856 - y2_output_root_mean_squared_error: 2.3355 - val_loss: 12.1695 - val_y1_output_loss: 5.4414 - val_y2_output_loss: 6.6941 - val_y1_output_root_mean_squared_error: 2.3588 - val_y2_output_root_mean_squared_error: 2.5701
# Epoch 41/100
# 614/614 [==============================] - 0s 183us/sample - loss: 10.1627 - y1_output_loss: 3.8098 - y2_output_loss: 6.4454 - y1_output_root_mean_squared_error: 1.9417 - y2_output_root_mean_squared_error: 2.5284 - val_loss: 17.9381 - val_y1_output_loss: 5.8024 - val_y2_output_loss: 12.0765 - val_y1_output_root_mean_squared_error: 2.4379 - val_y2_output_root_mean_squared_error: 3.4634
# Epoch 42/100
# 614/614 [==============================] - 0s 180us/sample - loss: 8.4001 - y1_output_loss: 3.0111 - y2_output_loss: 5.4022 - y1_output_root_mean_squared_error: 1.7284 - y2_output_root_mean_squared_error: 2.3266 - val_loss: 8.9136 - val_y1_output_loss: 3.9249 - val_y2_output_loss: 4.7416 - val_y1_output_root_mean_squared_error: 2.0134 - val_y2_output_root_mean_squared_error: 2.2045
# Epoch 43/100
# 614/614 [==============================] - 0s 177us/sample - loss: 9.1410 - y1_output_loss: 3.3081 - y2_output_loss: 5.8405 - y1_output_root_mean_squared_error: 1.8215 - y2_output_root_mean_squared_error: 2.4131 - val_loss: 8.6554 - val_y1_output_loss: 3.7682 - val_y2_output_loss: 4.7591 - val_y1_output_root_mean_squared_error: 1.9603 - val_y2_output_root_mean_squared_error: 2.1938
# Epoch 44/100
# 614/614 [==============================] - 0s 181us/sample - loss: 8.9930 - y1_output_loss: 3.1487 - y2_output_loss: 5.9896 - y1_output_root_mean_squared_error: 1.7720 - y2_output_root_mean_squared_error: 2.4193 - val_loss: 27.7510 - val_y1_output_loss: 7.2961 - val_y2_output_loss: 19.7093 - val_y1_output_root_mean_squared_error: 2.7317 - val_y2_output_root_mean_squared_error: 4.5043
# Epoch 45/100
# 614/614 [==============================] - 0s 175us/sample - loss: 7.4360 - y1_output_loss: 2.6980 - y2_output_loss: 4.7324 - y1_output_root_mean_squared_error: 1.6395 - y2_output_root_mean_squared_error: 2.1790 - val_loss: 8.2289 - val_y1_output_loss: 3.7556 - val_y2_output_loss: 4.3272 - val_y1_output_root_mean_squared_error: 1.9666 - val_y2_output_root_mean_squared_error: 2.0884
# Epoch 46/100
# 614/614 [==============================] - 0s 173us/sample - loss: 7.4309 - y1_output_loss: 2.6323 - y2_output_loss: 4.7552 - y1_output_root_mean_squared_error: 1.6266 - y2_output_root_mean_squared_error: 2.1875 - val_loss: 6.7779 - val_y1_output_loss: 2.7675 - val_y2_output_loss: 3.9709 - val_y1_output_root_mean_squared_error: 1.6904 - val_y2_output_root_mean_squared_error: 1.9800
# Epoch 47/100
# 614/614 [==============================] - 0s 194us/sample - loss: 8.3356 - y1_output_loss: 2.9007 - y2_output_loss: 5.6280 - y1_output_root_mean_squared_error: 1.6979 - y2_output_root_mean_squared_error: 2.3351 - val_loss: 12.7763 - val_y1_output_loss: 3.3726 - val_y2_output_loss: 9.0084 - val_y1_output_root_mean_squared_error: 1.8634 - val_y2_output_root_mean_squared_error: 3.0502
# Epoch 48/100
# 614/614 [==============================] - 0s 190us/sample - loss: 7.6582 - y1_output_loss: 2.6371 - y2_output_loss: 4.9548 - y1_output_root_mean_squared_error: 1.6314 - y2_output_root_mean_squared_error: 2.2353 - val_loss: 6.0267 - val_y1_output_loss: 2.5190 - val_y2_output_loss: 3.4428 - val_y1_output_root_mean_squared_error: 1.6099 - val_y2_output_root_mean_squared_error: 1.8534
# Epoch 49/100
# 614/614 [==============================] - 0s 201us/sample - loss: 7.2804 - y1_output_loss: 2.4695 - y2_output_loss: 4.7663 - y1_output_root_mean_squared_error: 1.5767 - y2_output_root_mean_squared_error: 2.1896 - val_loss: 7.1360 - val_y1_output_loss: 2.6683 - val_y2_output_loss: 4.2881 - val_y1_output_root_mean_squared_error: 1.6614 - val_y2_output_root_mean_squared_error: 2.0918
# Epoch 50/100
# 614/614 [==============================] - 0s 199us/sample - loss: 7.4643 - y1_output_loss: 2.5843 - y2_output_loss: 4.8868 - y1_output_root_mean_squared_error: 1.6034 - y2_output_root_mean_squared_error: 2.2121 - val_loss: 6.6245 - val_y1_output_loss: 2.6678 - val_y2_output_loss: 3.8217 - val_y1_output_root_mean_squared_error: 1.6584 - val_y2_output_root_mean_squared_error: 1.9683
# Epoch 51/100
# 614/614 [==============================] - 0s 183us/sample - loss: 8.3539 - y1_output_loss: 2.6732 - y2_output_loss: 5.6370 - y1_output_root_mean_squared_error: 1.6371 - y2_output_root_mean_squared_error: 2.3820 - val_loss: 6.0545 - val_y1_output_loss: 2.3937 - val_y2_output_loss: 3.5500 - val_y1_output_root_mean_squared_error: 1.5716 - val_y2_output_root_mean_squared_error: 1.8933
# Epoch 52/100
# 614/614 [==============================] - 0s 198us/sample - loss: 6.2736 - y1_output_loss: 2.0272 - y2_output_loss: 4.2003 - y1_output_root_mean_squared_error: 1.4291 - y2_output_root_mean_squared_error: 2.0570 - val_loss: 6.3400 - val_y1_output_loss: 2.4773 - val_y2_output_loss: 3.8633 - val_y1_output_root_mean_squared_error: 1.5926 - val_y2_output_root_mean_squared_error: 1.9503
# Epoch 53/100
# 614/614 [==============================] - 0s 181us/sample - loss: 6.4535 - y1_output_loss: 2.1891 - y2_output_loss: 4.2683 - y1_output_root_mean_squared_error: 1.4710 - y2_output_root_mean_squared_error: 2.0712 - val_loss: 5.8187 - val_y1_output_loss: 2.4185 - val_y2_output_loss: 3.3080 - val_y1_output_root_mean_squared_error: 1.5786 - val_y2_output_root_mean_squared_error: 1.8239
# Epoch 54/100
# 614/614 [==============================] - 0s 193us/sample - loss: 6.9379 - y1_output_loss: 2.1328 - y2_output_loss: 4.7856 - y1_output_root_mean_squared_error: 1.4645 - y2_output_root_mean_squared_error: 2.1893 - val_loss: 6.0224 - val_y1_output_loss: 2.1337 - val_y2_output_loss: 3.9386 - val_y1_output_root_mean_squared_error: 1.4749 - val_y2_output_root_mean_squared_error: 1.9614
# Epoch 55/100
# 614/614 [==============================] - 0s 186us/sample - loss: 5.7394 - y1_output_loss: 2.0648 - y2_output_loss: 3.6871 - y1_output_root_mean_squared_error: 1.4409 - y2_output_root_mean_squared_error: 1.9140 - val_loss: 6.1063 - val_y1_output_loss: 2.1528 - val_y2_output_loss: 3.8938 - val_y1_output_root_mean_squared_error: 1.4827 - val_y2_output_root_mean_squared_error: 1.9768
# Epoch 56/100
# 614/614 [==============================] - 0s 171us/sample - loss: 6.5652 - y1_output_loss: 2.2404 - y2_output_loss: 4.2728 - y1_output_root_mean_squared_error: 1.5031 - y2_output_root_mean_squared_error: 2.0751 - val_loss: 5.3216 - val_y1_output_loss: 1.9335 - val_y2_output_loss: 3.3649 - val_y1_output_root_mean_squared_error: 1.4078 - val_y2_output_root_mean_squared_error: 1.8275
# Epoch 57/100
# 614/614 [==============================] - 0s 201us/sample - loss: 5.8689 - y1_output_loss: 1.9662 - y2_output_loss: 3.8593 - y1_output_root_mean_squared_error: 1.4083 - y2_output_root_mean_squared_error: 1.9712 - val_loss: 11.4485 - val_y1_output_loss: 3.6842 - val_y2_output_loss: 7.8448 - val_y1_output_root_mean_squared_error: 1.9310 - val_y2_output_root_mean_squared_error: 2.7784
# Epoch 58/100
# 614/614 [==============================] - 0s 179us/sample - loss: 5.9947 - y1_output_loss: 1.8825 - y2_output_loss: 4.1031 - y1_output_root_mean_squared_error: 1.3632 - y2_output_root_mean_squared_error: 2.0338 - val_loss: 8.5764 - val_y1_output_loss: 2.3230 - val_y2_output_loss: 6.2989 - val_y1_output_root_mean_squared_error: 1.5363 - val_y2_output_root_mean_squared_error: 2.4932
# Epoch 59/100
# 614/614 [==============================] - 0s 179us/sample - loss: 6.6388 - y1_output_loss: 2.0676 - y2_output_loss: 4.5729 - y1_output_root_mean_squared_error: 1.4355 - y2_output_root_mean_squared_error: 2.1397 - val_loss: 6.0107 - val_y1_output_loss: 2.4101 - val_y2_output_loss: 3.5998 - val_y1_output_root_mean_squared_error: 1.5673 - val_y2_output_root_mean_squared_error: 1.8853
# Epoch 60/100
# 614/614 [==============================] - 0s 175us/sample - loss: 5.6608 - y1_output_loss: 1.8002 - y2_output_loss: 3.8246 - y1_output_root_mean_squared_error: 1.3425 - y2_output_root_mean_squared_error: 1.9643 - val_loss: 8.1129 - val_y1_output_loss: 2.8469 - val_y2_output_loss: 5.0154 - val_y1_output_root_mean_squared_error: 1.7145 - val_y2_output_root_mean_squared_error: 2.2745
# Epoch 61/100
# 614/614 [==============================] - 0s 173us/sample - loss: 6.3069 - y1_output_loss: 2.0235 - y2_output_loss: 4.2401 - y1_output_root_mean_squared_error: 1.4270 - y2_output_root_mean_squared_error: 2.0665 - val_loss: 4.8963 - val_y1_output_loss: 1.6769 - val_y2_output_loss: 3.2029 - val_y1_output_root_mean_squared_error: 1.3059 - val_y2_output_root_mean_squared_error: 1.7863
# Epoch 62/100
# 614/614 [==============================] - 0s 196us/sample - loss: 5.2134 - y1_output_loss: 1.7350 - y2_output_loss: 3.4456 - y1_output_root_mean_squared_error: 1.3216 - y2_output_root_mean_squared_error: 1.8619 - val_loss: 5.3577 - val_y1_output_loss: 1.7939 - val_y2_output_loss: 3.4731 - val_y1_output_root_mean_squared_error: 1.3617 - val_y2_output_root_mean_squared_error: 1.8718
# Epoch 63/100
# 614/614 [==============================] - 0s 170us/sample - loss: 6.9310 - y1_output_loss: 2.3265 - y2_output_loss: 4.7065 - y1_output_root_mean_squared_error: 1.5126 - y2_output_root_mean_squared_error: 2.1548 - val_loss: 14.6891 - val_y1_output_loss: 3.7269 - val_y2_output_loss: 10.9485 - val_y1_output_root_mean_squared_error: 1.9439 - val_y2_output_root_mean_squared_error: 3.3031
# Epoch 64/100
# 614/614 [==============================] - 0s 192us/sample - loss: 5.1376 - y1_output_loss: 1.6460 - y2_output_loss: 3.5313 - y1_output_root_mean_squared_error: 1.2875 - y2_output_root_mean_squared_error: 1.8654 - val_loss: 10.8531 - val_y1_output_loss: 3.0612 - val_y2_output_loss: 7.5625 - val_y1_output_root_mean_squared_error: 1.7608 - val_y2_output_root_mean_squared_error: 2.7844
# Epoch 65/100
# 614/614 [==============================] - 0s 169us/sample - loss: 4.4311 - y1_output_loss: 1.4010 - y2_output_loss: 3.0280 - y1_output_root_mean_squared_error: 1.1879 - y2_output_root_mean_squared_error: 1.7378 - val_loss: 5.7992 - val_y1_output_loss: 1.6567 - val_y2_output_loss: 4.0267 - val_y1_output_root_mean_squared_error: 1.3057 - val_y2_output_root_mean_squared_error: 2.0234
# Epoch 66/100
# 614/614 [==============================] - 0s 188us/sample - loss: 4.5261 - y1_output_loss: 1.3919 - y2_output_loss: 3.1135 - y1_output_root_mean_squared_error: 1.1816 - y2_output_root_mean_squared_error: 1.7692 - val_loss: 5.6156 - val_y1_output_loss: 2.3362 - val_y2_output_loss: 3.1839 - val_y1_output_root_mean_squared_error: 1.5556 - val_y2_output_root_mean_squared_error: 1.7876
# Epoch 67/100
# 614/614 [==============================] - 0s 192us/sample - loss: 6.9758 - y1_output_loss: 2.1428 - y2_output_loss: 4.7814 - y1_output_root_mean_squared_error: 1.4677 - y2_output_root_mean_squared_error: 2.1958 - val_loss: 4.9697 - val_y1_output_loss: 1.5684 - val_y2_output_loss: 3.2657 - val_y1_output_root_mean_squared_error: 1.2732 - val_y2_output_root_mean_squared_error: 1.8299
# Epoch 68/100
# 614/614 [==============================] - 0s 182us/sample - loss: 4.2666 - y1_output_loss: 1.3943 - y2_output_loss: 2.8636 - y1_output_root_mean_squared_error: 1.1817 - y2_output_root_mean_squared_error: 1.6942 - val_loss: 5.5528 - val_y1_output_loss: 1.8373 - val_y2_output_loss: 3.6414 - val_y1_output_root_mean_squared_error: 1.3781 - val_y2_output_root_mean_squared_error: 1.9114
# Epoch 69/100
# 614/614 [==============================] - 0s 179us/sample - loss: 4.0059 - y1_output_loss: 1.3616 - y2_output_loss: 2.6322 - y1_output_root_mean_squared_error: 1.1633 - y2_output_root_mean_squared_error: 1.6287 - val_loss: 5.7755 - val_y1_output_loss: 1.8820 - val_y2_output_loss: 3.7523 - val_y1_output_root_mean_squared_error: 1.3918 - val_y2_output_root_mean_squared_error: 1.9592
# Epoch 70/100
# 614/614 [==============================] - 0s 166us/sample - loss: 4.4984 - y1_output_loss: 1.4243 - y2_output_loss: 3.1214 - y1_output_root_mean_squared_error: 1.1930 - y2_output_root_mean_squared_error: 1.7536 - val_loss: 11.1832 - val_y1_output_loss: 3.5000 - val_y2_output_loss: 7.5647 - val_y1_output_root_mean_squared_error: 1.9033 - val_y2_output_root_mean_squared_error: 2.7497
# Epoch 71/100
# 614/614 [==============================] - 0s 194us/sample - loss: 4.2306 - y1_output_loss: 1.3691 - y2_output_loss: 2.8559 - y1_output_root_mean_squared_error: 1.1752 - y2_output_root_mean_squared_error: 1.6881 - val_loss: 8.3599 - val_y1_output_loss: 1.9527 - val_y2_output_loss: 6.1121 - val_y1_output_root_mean_squared_error: 1.4235 - val_y2_output_root_mean_squared_error: 2.5167
# Epoch 72/100
# 614/614 [==============================] - 0s 176us/sample - loss: 4.0768 - y1_output_loss: 1.3546 - y2_output_loss: 2.7142 - y1_output_root_mean_squared_error: 1.1630 - y2_output_root_mean_squared_error: 1.6505 - val_loss: 5.2132 - val_y1_output_loss: 1.9052 - val_y2_output_loss: 3.1730 - val_y1_output_root_mean_squared_error: 1.3976 - val_y2_output_root_mean_squared_error: 1.8055
# Epoch 73/100
# 614/614 [==============================] - 0s 188us/sample - loss: 5.0869 - y1_output_loss: 1.7834 - y2_output_loss: 3.2813 - y1_output_root_mean_squared_error: 1.3373 - y2_output_root_mean_squared_error: 1.8162 - val_loss: 7.2238 - val_y1_output_loss: 1.9607 - val_y2_output_loss: 5.3716 - val_y1_output_root_mean_squared_error: 1.4117 - val_y2_output_root_mean_squared_error: 2.2871
# Epoch 74/100
# 614/614 [==============================] - 0s 179us/sample - loss: 5.9875 - y1_output_loss: 1.5955 - y2_output_loss: 4.3419 - y1_output_root_mean_squared_error: 1.2679 - y2_output_root_mean_squared_error: 2.0928 - val_loss: 5.9544 - val_y1_output_loss: 2.1243 - val_y2_output_loss: 3.8345 - val_y1_output_root_mean_squared_error: 1.4656 - val_y2_output_root_mean_squared_error: 1.9510
# Epoch 75/100
# 614/614 [==============================] - 0s 169us/sample - loss: 3.9775 - y1_output_loss: 1.1763 - y2_output_loss: 2.7659 - y1_output_root_mean_squared_error: 1.0893 - y2_output_root_mean_squared_error: 1.6706 - val_loss: 4.6143 - val_y1_output_loss: 1.4420 - val_y2_output_loss: 3.0510 - val_y1_output_root_mean_squared_error: 1.2206 - val_y2_output_root_mean_squared_error: 1.7677
# Epoch 76/100
# 614/614 [==============================] - 0s 182us/sample - loss: 3.4937 - y1_output_loss: 1.0833 - y2_output_loss: 2.4285 - y1_output_root_mean_squared_error: 1.0430 - y2_output_root_mean_squared_error: 1.5511 - val_loss: 4.4835 - val_y1_output_loss: 1.1914 - val_y2_output_loss: 3.3187 - val_y1_output_root_mean_squared_error: 1.1075 - val_y2_output_root_mean_squared_error: 1.8047
# Epoch 77/100
# 614/614 [==============================] - 0s 186us/sample - loss: 3.3787 - y1_output_loss: 0.9483 - y2_output_loss: 2.4132 - y1_output_root_mean_squared_error: 0.9753 - y2_output_root_mean_squared_error: 1.5580 - val_loss: 3.9086 - val_y1_output_loss: 1.1222 - val_y2_output_loss: 2.7692 - val_y1_output_root_mean_squared_error: 1.0694 - val_y2_output_root_mean_squared_error: 1.6628
# Epoch 78/100
# 614/614 [==============================] - 0s 196us/sample - loss: 4.5585 - y1_output_loss: 1.2896 - y2_output_loss: 3.2594 - y1_output_root_mean_squared_error: 1.1334 - y2_output_root_mean_squared_error: 1.8094 - val_loss: 4.4582 - val_y1_output_loss: 1.6359 - val_y2_output_loss: 2.8157 - val_y1_output_root_mean_squared_error: 1.2964 - val_y2_output_root_mean_squared_error: 1.6666
# Epoch 79/100
# 614/614 [==============================] - 0s 188us/sample - loss: 3.9400 - y1_output_loss: 1.2667 - y2_output_loss: 2.6624 - y1_output_root_mean_squared_error: 1.1283 - y2_output_root_mean_squared_error: 1.6331 - val_loss: 4.4807 - val_y1_output_loss: 1.4015 - val_y2_output_loss: 3.0885 - val_y1_output_root_mean_squared_error: 1.1943 - val_y2_output_root_mean_squared_error: 1.7477
# Epoch 80/100
# 614/614 [==============================] - 0s 186us/sample - loss: 3.2100 - y1_output_loss: 0.9965 - y2_output_loss: 2.2340 - y1_output_root_mean_squared_error: 0.9939 - y2_output_root_mean_squared_error: 1.4907 - val_loss: 16.0698 - val_y1_output_loss: 3.9643 - val_y2_output_loss: 11.6703 - val_y1_output_root_mean_squared_error: 2.0103 - val_y2_output_root_mean_squared_error: 3.4682
# Epoch 81/100
# 614/614 [==============================] - 0s 187us/sample - loss: 5.3020 - y1_output_loss: 1.4709 - y2_output_loss: 3.7848 - y1_output_root_mean_squared_error: 1.2171 - y2_output_root_mean_squared_error: 1.9547 - val_loss: 4.4991 - val_y1_output_loss: 1.3528 - val_y2_output_loss: 3.0242 - val_y1_output_root_mean_squared_error: 1.1818 - val_y2_output_root_mean_squared_error: 1.7614
# Epoch 82/100
# 614/614 [==============================] - 0s 165us/sample - loss: 3.7632 - y1_output_loss: 1.1568 - y2_output_loss: 2.6059 - y1_output_root_mean_squared_error: 1.0775 - y2_output_root_mean_squared_error: 1.6132 - val_loss: 7.5200 - val_y1_output_loss: 2.3808 - val_y2_output_loss: 4.9390 - val_y1_output_root_mean_squared_error: 1.5546 - val_y2_output_root_mean_squared_error: 2.2590
# Epoch 83/100
# 614/614 [==============================] - 0s 172us/sample - loss: 4.0586 - y1_output_loss: 1.1061 - y2_output_loss: 2.9512 - y1_output_root_mean_squared_error: 1.0512 - y2_output_root_mean_squared_error: 1.7186 - val_loss: 3.9630 - val_y1_output_loss: 1.0331 - val_y2_output_loss: 2.8658 - val_y1_output_root_mean_squared_error: 1.0193 - val_y2_output_root_mean_squared_error: 1.7100
# Epoch 84/100
# 614/614 [==============================] - 0s 183us/sample - loss: 3.1320 - y1_output_loss: 0.9413 - y2_output_loss: 2.1981 - y1_output_root_mean_squared_error: 0.9697 - y2_output_root_mean_squared_error: 1.4804 - val_loss: 7.4271 - val_y1_output_loss: 1.0122 - val_y2_output_loss: 6.4925 - val_y1_output_root_mean_squared_error: 1.0116 - val_y2_output_root_mean_squared_error: 2.5306
# Epoch 85/100
# 614/614 [==============================] - 0s 187us/sample - loss: 3.3908 - y1_output_loss: 1.0523 - y2_output_loss: 2.3604 - y1_output_root_mean_squared_error: 1.0215 - y2_output_root_mean_squared_error: 1.5321 - val_loss: 9.0022 - val_y1_output_loss: 2.3162 - val_y2_output_loss: 6.5454 - val_y1_output_root_mean_squared_error: 1.5483 - val_y2_output_root_mean_squared_error: 2.5700
# Epoch 86/100
# 614/614 [==============================] - 0s 180us/sample - loss: 5.4624 - y1_output_loss: 1.3557 - y2_output_loss: 4.0565 - y1_output_root_mean_squared_error: 1.1694 - y2_output_root_mean_squared_error: 2.0236 - val_loss: 3.5402 - val_y1_output_loss: 0.9278 - val_y2_output_loss: 2.5960 - val_y1_output_root_mean_squared_error: 0.9745 - val_y2_output_root_mean_squared_error: 1.6095
# Epoch 87/100
# 614/614 [==============================] - 0s 196us/sample - loss: 3.0426 - y1_output_loss: 0.8568 - y2_output_loss: 2.1932 - y1_output_root_mean_squared_error: 0.9218 - y2_output_root_mean_squared_error: 1.4809 - val_loss: 3.1956 - val_y1_output_loss: 0.9381 - val_y2_output_loss: 2.2486 - val_y1_output_root_mean_squared_error: 0.9805 - val_y2_output_root_mean_squared_error: 1.4947
# Epoch 88/100
# 614/614 [==============================] - 0s 182us/sample - loss: 2.7005 - y1_output_loss: 0.8611 - y2_output_loss: 1.8445 - y1_output_root_mean_squared_error: 0.9304 - y2_output_root_mean_squared_error: 1.3546 - val_loss: 4.3184 - val_y1_output_loss: 0.8478 - val_y2_output_loss: 3.4718 - val_y1_output_root_mean_squared_error: 0.9306 - val_y2_output_root_mean_squared_error: 1.8580
# Epoch 89/100
# 614/614 [==============================] - 0s 172us/sample - loss: 3.5316 - y1_output_loss: 0.9962 - y2_output_loss: 2.5364 - y1_output_root_mean_squared_error: 1.0019 - y2_output_root_mean_squared_error: 1.5899 - val_loss: 5.7572 - val_y1_output_loss: 1.3244 - val_y2_output_loss: 4.2503 - val_y1_output_root_mean_squared_error: 1.1675 - val_y2_output_root_mean_squared_error: 2.0962
# Epoch 90/100
# 614/614 [==============================] - 0s 163us/sample - loss: 3.9004 - y1_output_loss: 1.1289 - y2_output_loss: 2.7471 - y1_output_root_mean_squared_error: 1.0641 - y2_output_root_mean_squared_error: 1.6638 - val_loss: 3.5420 - val_y1_output_loss: 0.7807 - val_y2_output_loss: 2.7662 - val_y1_output_root_mean_squared_error: 0.8949 - val_y2_output_root_mean_squared_error: 1.6556
# Epoch 91/100
# 614/614 [==============================] - 0s 206us/sample - loss: 4.9639 - y1_output_loss: 1.2721 - y2_output_loss: 3.6521 - y1_output_root_mean_squared_error: 1.1314 - y2_output_root_mean_squared_error: 1.9193 - val_loss: 3.7831 - val_y1_output_loss: 0.9069 - val_y2_output_loss: 2.8607 - val_y1_output_root_mean_squared_error: 0.9676 - val_y2_output_root_mean_squared_error: 1.6873
# Epoch 92/100
# 614/614 [==============================] - 0s 194us/sample - loss: 2.7519 - y1_output_loss: 0.7272 - y2_output_loss: 2.0024 - y1_output_root_mean_squared_error: 0.8556 - y2_output_root_mean_squared_error: 1.4212 - val_loss: 3.8713 - val_y1_output_loss: 1.1681 - val_y2_output_loss: 2.6999 - val_y1_output_root_mean_squared_error: 1.0746 - val_y2_output_root_mean_squared_error: 1.6482
# Epoch 93/100
# 614/614 [==============================] - 0s 184us/sample - loss: 2.6816 - y1_output_loss: 0.7149 - y2_output_loss: 1.9553 - y1_output_root_mean_squared_error: 0.8488 - y2_output_root_mean_squared_error: 1.4004 - val_loss: 5.1899 - val_y1_output_loss: 0.9478 - val_y2_output_loss: 4.2769 - val_y1_output_root_mean_squared_error: 0.9798 - val_y2_output_root_mean_squared_error: 2.0567
# Epoch 94/100
# 614/614 [==============================] - 0s 186us/sample - loss: 2.6716 - y1_output_loss: 0.7382 - y2_output_loss: 1.9456 - y1_output_root_mean_squared_error: 0.8591 - y2_output_root_mean_squared_error: 1.3905 - val_loss: 3.6980 - val_y1_output_loss: 0.7871 - val_y2_output_loss: 2.9228 - val_y1_output_root_mean_squared_error: 0.8938 - val_y2_output_root_mean_squared_error: 1.7027
# Epoch 95/100
# 614/614 [==============================] - 0s 204us/sample - loss: 2.1853 - y1_output_loss: 0.6091 - y2_output_loss: 1.5701 - y1_output_root_mean_squared_error: 0.7806 - y2_output_root_mean_squared_error: 1.2554 - val_loss: 4.3055 - val_y1_output_loss: 1.5511 - val_y2_output_loss: 2.6851 - val_y1_output_root_mean_squared_error: 1.2648 - val_y2_output_root_mean_squared_error: 1.6449
# Epoch 96/100
# 614/614 [==============================] - 0s 195us/sample - loss: 2.4356 - y1_output_loss: 0.6222 - y2_output_loss: 1.7979 - y1_output_root_mean_squared_error: 0.7893 - y2_output_root_mean_squared_error: 1.3463 - val_loss: 3.0534 - val_y1_output_loss: 1.0062 - val_y2_output_loss: 2.0216 - val_y1_output_root_mean_squared_error: 1.0031 - val_y2_output_root_mean_squared_error: 1.4308
# Epoch 97/100
# 614/614 [==============================] - 0s 177us/sample - loss: 2.7648 - y1_output_loss: 0.8118 - y2_output_loss: 1.9411 - y1_output_root_mean_squared_error: 0.9035 - y2_output_root_mean_squared_error: 1.3958 - val_loss: 2.8435 - val_y1_output_loss: 0.6950 - val_y2_output_loss: 2.1041 - val_y1_output_root_mean_squared_error: 0.8412 - val_y2_output_root_mean_squared_error: 1.4615
# Epoch 98/100
# 614/614 [==============================] - 0s 187us/sample - loss: 3.8234 - y1_output_loss: 1.1085 - y2_output_loss: 2.7133 - y1_output_root_mean_squared_error: 1.0555 - y2_output_root_mean_squared_error: 1.6460 - val_loss: 6.4060 - val_y1_output_loss: 1.2940 - val_y2_output_loss: 4.8837 - val_y1_output_root_mean_squared_error: 1.1552 - val_y2_output_root_mean_squared_error: 2.2520
# Epoch 99/100
# 614/614 [==============================] - 0s 168us/sample - loss: 6.6313 - y1_output_loss: 2.0300 - y2_output_loss: 4.5958 - y1_output_root_mean_squared_error: 1.4300 - y2_output_root_mean_squared_error: 2.1416 - val_loss: 8.8310 - val_y1_output_loss: 2.3559 - val_y2_output_loss: 6.3538 - val_y1_output_root_mean_squared_error: 1.5344 - val_y2_output_root_mean_squared_error: 2.5449
# Epoch 100/100
# 614/614 [==============================] - 0s 162us/sample - loss: 2.4895 - y1_output_loss: 0.6487 - y2_output_loss: 1.8360 - y1_output_root_mean_squared_error: 0.8087 - y2_output_root_mean_squared_error: 1.3548 - val_loss: 3.0120 - val_y1_output_loss: 0.6742 - val_y2_output_loss: 2.2605 - val_y1_output_root_mean_squared_error: 0.8305 - val_y2_output_root_mean_squared_error: 1.5239

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 50us/sample - loss: 3.0120 - y1_output_loss: 0.6933 - y2_output_loss: 2.3705 - y1_output_root_mean_squared_error: 0.8305 - y2_output_root_mean_squared_error: 1.5239
# Loss = 3.0119534281941203, Y1_loss = 0.6932809948921204, Y1_mse = 0.830528736114502, Y2_loss = 2.3704519271850586, Y2_mse = 1.5238686800003052

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
